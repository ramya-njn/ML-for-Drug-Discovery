# %% [markdown]
# ## **Predicting Drug Induced Liver Injury: Analysing Data Bias**
#
#
#
#
#
# **Dataset** : Toxicological Sciences, Volume 136, Issue 1, November 2013, Pages 242–249, https://doi.org/10.1093/toxsci/kft189

# %% [markdown]
# ### **Import Libraries**

# %%
# !pip install rdkit-pypi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: rdkit-pypi in /usr/local/lib/python3.9/dist-packages (2022.9.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from rdkit-pypi) (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from rdkit-pypi) (8.4.0)

# %%
# !pip install molvs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: molvs in /usr/local/lib/python3.9/dist-packages (0.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from molvs) (1.15.0)

# %%
import os

# Base Libraries
import numpy as np
import pandas as pd

# RDKit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit import rdBase
from rdkit.Chem.Scaffolds import MurckoScaffold
from rdkit.Chem import DataStructs  

# molvs
from molvs import standardize_smiles

# SKlearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# ###  **Get Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir('/content/drive/My Drive/')

# %%
s1=pd.read_excel('toxsci_13_0303_File013.xls', sheet_name=0)
print(s1.shape)
s1.head()
# Out:
# (197, 3)
#    PubChem CompoundName Drug label-based annotation
# 0     3474    glafenine           Most DILI-concern
# 1     2478     busulfan           Most DILI-concern
# 2     2520    verapamil           Most DILI-concern
# 3     2662    celecoxib           Most DILI-concern
# 4     2898   cyclofenil           Most DILI-concern

# %%
s2=pd.read_excel('toxsci_13_0303_File013.xls', sheet_name=1)
print(s2.shape)
s2.head()
# Out:
# (190, 4)
#    PubChem CompoundName Drug label-based annotation  QSAR Prediction
# 0    28417      danazol           Most DILI-concern                0
# 1    65027   tipranavir           Most DILI-concern                1
# 2    50599   didanosine           Most DILI-concern                1
# 3    18283    stavudine           Most DILI-concern                1
# 4    60825   lamivudine           Most DILI-concern                1

# %% [markdown]
# ### **Get corresponding Smiles data for molecules in s1 and s2 from PubChem database**

# %%
x1=pd.read_csv('Supp1.csv')
print(x1.shape)
x1.head(2)
# Out:
# (193, 24)
#    cid                                           cmpdname  \
# 0  298  2,2-dichloro-N-[1,3-dihydroxy-1-(4-nitrophenyl...
# 1  338                                     Salicylic Acid
#
#                                          cmpdsynonym      mw             mf  \
# 0  579-51-1|2,2-dichloro-N-[1,3-dihydroxy-1-(4-ni...  323.13  C11H12Cl2N2O5
# 1  salicylic acid|2-Hydroxybenzoic acid|69-72-7|o...  138.12         C7H6O3
#
#    polararea  complexity  xlogp  heavycnt  hbonddonor  ...  \
# 0      115.0       342.0    1.1        20           3  ...
# 1       57.5       133.0    2.3        10           2  ...
#
#                       inchikey  \
# 0  WIIZWVCIJKGZOK-UHFFFAOYSA-N
# 1  YGSDEFSMJLZEOE-UHFFFAOYSA-N
#
#                                            iupacname    meshheadings  \
# 0  2,2-dichloro-N-[1,3-dihydroxy-1-(4-nitrophenyl...             NaN
# 1                              2-hydroxybenzoic acid  Salicylic Acid
#
#                                            annothits annothitcnt  \
# 0  Biological Test Results|Chemical and Physical ...           9
# 1  Biological Test Results|Chemical and Physical ...          13
#
#                                                 aids  cidcdate  \
# 0  155|157|175|248|256|328|485|631|731|757|758|75...  20050325
# 1  155|157|161|165|167|175|179|248|485|568|583|59...  20040916
#
#                                           sidsrcname  \
# 0  001Chemical|AAA Chemistry|abcr GmbH|ABI Chem|A...
# 1  001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
#
#                                              depcatg annotation
# 0  Chemical Vendors|Curation Efforts|Governmental...        NaN
# 1  Chemical Vendors|Curation Efforts|Governmental...        NaN
#
# [2 rows x 24 columns]

# %%
x2=pd.read_csv('Supp2.csv')
print(x2.shape)
x2.head(2)
# Out:
# (184, 24)
#    cid cmpdname                                        cmpdsynonym      mw  \
# 0  247  Betaine  betaine|107-43-7|glycine betaine|oxyneurine|Tr...  117.15
# 1  453  Hexitol  Hexitol|hexane-1,2,3,4,5,6-hexol|hexane-1,2,3,...  182.17
#
#          mf  polararea  complexity  xlogp  heavycnt  hbonddonor  ...  \
# 0  C5H11NO2       40.1        87.6    0.5         8           0  ...
# 1   C6H14O6      121.0       105.0   -3.1        12           6  ...
#
#                       inchikey                      iupacname meshheadings  \
# 0  KWIUHFFTVRNATP-UHFFFAOYSA-N  2-(trimethylazaniumyl)acetate      Betaine
# 1  FBPFZTCFMRRESA-UHFFFAOYSA-N       hexane-1,2,3,4,5,6-hexol          NaN
#
#                                            annothits annothitcnt  \
# 0  Biological Test Results|Chemical and Physical ...          13
# 1  Biological Test Results|Classification|Literat...           6
#
#                                                 aids  cidcdate  \
# 0  192|248|608|1033|1195|1549|1552|1637|1648|7104...  20040916
# 1  155|157|161|165|167|175|188|200|208|214|220|24...  20050325
#
#                                           sidsrcname  \
# 0  001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
# 1  001Chemical|3B Scientific (Wuhan) Corp|3WAY PH...
#
#                                              depcatg annotation
# 0  Chemical Vendors|Curation Efforts|Governmental...        NaN
# 1  Chemical Vendors|Curation Efforts|Governmental...        NaN
#
# [2 rows x 24 columns]

# %%
# Take only columns 'cid' and 'isosmiles'
x1=x1[['cid', 'isosmiles']]
x2=x2[['cid', 'isosmiles']]

# %% [markdown]
# ### **Merge (s1,x1) and (s2,x2) on PubChem id and combine**

# %%
s1=s1.rename(columns={'PubChem':'cid'})
s2=s2.rename(columns={'PubChem':'cid'})

# %%
merged_1=pd.merge(s1, x1, on='cid')
merged_2=pd.merge(s2, x2, on='cid')

# %%
print(merged_1.shape)
print(merged_2.shape)
# Out:
# (193, 4)
# (184, 5)

# %%
combined=pd.concat([merged_1, merged_2], axis=0)
combined.drop(['QSAR Prediction'], axis=1, inplace=True)
combined=combined.reset_index(drop=True)
print(combined.shape)
combined.head()
# Out:
# (377, 4)
#     cid CompoundName Drug label-based annotation  \
# 0  3474    glafenine           Most DILI-concern
# 1  2478     busulfan           Most DILI-concern
# 2  2520    verapamil           Most DILI-concern
# 3  2662    celecoxib           Most DILI-concern
# 4  2898   cyclofenil           Most DILI-concern
#
#                                            isosmiles
# 0  C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...
# 1                         CS(=O)(=O)OCCCCOS(=O)(=O)C
# 2  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...
# 3  CC1=CC=C(C=C1)C2=CC(=NN2C3=CC=C(C=C3)S(=O)(=O)...
# 4  CC(=O)OC1=CC=C(C=C1)C(=C2CCCCC2)C3=CC=C(C=C3)O...

# %%
combined.to_csv('DILI_dataset.csv', index=None)

# %% [markdown]
# ### **Create DILI_positive and DILI_negative datasets**

# %%
combined['Drug label-based annotation'].value_counts()
# Out:
# no DILI-concern      209
# Most DILI-concern    168
# Name: Drug label-based annotation, dtype: int64

# %%
DILI_positive=combined[combined['Drug label-based annotation']=='Most DILI-concern']
DILI_positive['label']=1
DILI_positive.head(3)
# Out:
# <ipython-input-17-55d179dde922>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DILI_positive['label']=1
#     cid CompoundName Drug label-based annotation  \
# 0  3474    glafenine           Most DILI-concern
# 1  2478     busulfan           Most DILI-concern
# 2  2520    verapamil           Most DILI-concern
#
#                                            isosmiles  label
# 0  C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...      1
# 1                         CS(=O)(=O)OCCCCOS(=O)(=O)C      1
# 2  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...      1

# %%
DILI_negative=combined[combined['Drug label-based annotation']=='no DILI-concern']
DILI_negative['label']=0
DILI_negative.head(3)
# Out:
# <ipython-input-18-ac7b7442935d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DILI_negative['label']=0
#      cid     CompoundName Drug label-based annotation  \
# 77  3100  diphenhydramine             no DILI-concern
# 78  3354        flavoxate             no DILI-concern
# 79  2370      bethanechol             no DILI-concern
#
#                                             isosmiles  label
# 77                  CN(C)CCOC(C1=CC=CC=C1)C2=CC=CC=C2      0
# 78  CC1=C(OC2=C(C1=O)C=CC=C2C(=O)OCCN3CCCCC3)C4=CC...      0
# 79                            CC(C[N+](C)(C)C)OC(=O)N      0

# %%
DILI=pd.concat([DILI_positive, DILI_negative], axis=0)
DILI=DILI.reset_index(drop=True)
DILI
# Out:
#           cid           CompoundName Drug label-based annotation  \
# 0        3474              glafenine           Most DILI-concern
# 1        2478               busulfan           Most DILI-concern
# 2        2520              verapamil           Most DILI-concern
# 3        2662              celecoxib           Most DILI-concern
# 4        2898             cyclofenil           Most DILI-concern
# ..        ...                    ...                         ...
# 372  54678501              vitamin c             no DILI-concern
# 373      2707        chloral hydrate             no DILI-concern
# 374     24705            dimethicone             no DILI-concern
# 375      2341          benzphetamine             no DILI-concern
# 376  16129703  desirudin recombinant             no DILI-concern
#
#                                              isosmiles  label
# 0    C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...      1
# 1                           CS(=O)(=O)OCCCCOS(=O)(=O)C      1
# 2    CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...      1
# 3    CC1=CC=C(C=C1)C2=CC(=NN2C3=CC=C(C=C3)S(=O)(=O)...      1
# 4    CC(=O)OC1=CC=C(C=C1)C(=C2CCCCC2)C3=CC=C(C=C3)O...      1
# ..                                                 ...    ...
# 372                    C([C@@H](C1C(=C(C(=O)O1)O)O)O)O      0
# 373                                 C(C(Cl)(Cl)Cl)(O)O      0
# 374                 C[Si](C)(C)O[Si](C)(C)O[Si](C)(C)C      0
# 375                   CC(CC1=CC=CC=C1)N(C)CC2=CC=CC=C2      0
# 376  CC[C@H](C)[C@H]1C(=O)N[C@H](C(=O)NCC(=O)N[C@H]...      0
#
# [377 rows x 5 columns]

# %%
DILI = DILI.drop(labels=[186,187,193,376], axis=0)
DILI=DILI.reset_index(drop=True)
DILI.shape
# Out:
# (373, 5)

# %%
DILI.to_csv('DILI-labelled.csv')

# %%
std_smi=[standardize_smiles(smi) for smi in DILI['isosmiles'] if smi is not None]
stdsmi=pd.DataFrame(std_smi, columns=['STD_SMILES'])
print(stdsmi.shape)
stdsmi.head(3)
# Out:
# (373, 1)
#                                           STD_SMILES
# 0           O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12
# 1                         CS(=O)(=O)OCCCCOS(C)(=O)=O
# 2  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...

# %%
DILI=pd.concat([DILI, stdsmi], axis=1)
print(DILI.shape)
DILI.head(3)
# Out:
# (373, 6)
#     cid CompoundName Drug label-based annotation  \
# 0  3474    glafenine           Most DILI-concern
# 1  2478     busulfan           Most DILI-concern
# 2  2520    verapamil           Most DILI-concern
#
#                                            isosmiles  label  \
# 0  C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...      1
# 1                         CS(=O)(=O)OCCCCOS(=O)(=O)C      1
# 2  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...      1
#
#                                           STD_SMILES
# 0           O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12
# 1                         CS(=O)(=O)OCCCCOS(C)(=O)=O
# 2  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...

# %%
DILI['New_ID']=DILI['cid'].astype(str)+'_'+DILI['label'].astype(str)
DILI.head(3)
# Out:
#     cid CompoundName Drug label-based annotation  \
# 0  3474    glafenine           Most DILI-concern
# 1  2478     busulfan           Most DILI-concern
# 2  2520    verapamil           Most DILI-concern
#
#                                            isosmiles  label  \
# 0  C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...      1
# 1                         CS(=O)(=O)OCCCCOS(=O)(=O)C      1
# 2  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...      1
#
#                                           STD_SMILES  New_ID
# 0           O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12  3474_1
# 1                         CS(=O)(=O)OCCCCOS(C)(=O)=O  2478_1
# 2  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...  2520_1

# %% [markdown]
# ## **Analyze Chemical Bias via Asymmetric Validation Embedding (AVE) 3 ways:**
#
# 1) Random Split
#
# 2) Molecular Clustering
#
# 3) Scaffold-based clustering

# %% [markdown]
# ### **Model 1: Train/Test Random Split**

# %%
X_train, X_test, y_train, y_test = train_test_split(DILI['STD_SMILES'], DILI['New_ID'], test_size=0.2, random_state=42, shuffle=True)

# %%
train1=pd.concat([X_train, y_train], axis=1)
test1=pd.concat([X_test, y_test], axis=1)
print(train1.shape)
print(test1.shape)
# Out:
# (298, 2)
# (75, 2)

# %%
train1.head(3)
# Out:
#                                             STD_SMILES     New_ID
# 192  CC(=CCC1=C(C)C(=O)c2ccccc2C1=O)CCCC(C)CCCC(C)C...     4812_0
# 75        CN1CCC(Nc2ncc3ncnc(Nc4ccc(F)c(Cl)c4)c3n2)CC1  6918508_1
# 84   Cc1nnc(C(C)C)n1C1C[C@H]2CC[C@@H](C1)N2CC[C@H](...  3002977_1

# %%
train_rand=train1['New_ID'].str.split('_', n=1, expand=True)
train_rand.columns=['cid', 'label']
train_rand=train_rand[['cid', 'label']].astype(np.int64)
train_rand=pd.concat([train1['STD_SMILES'], train_rand], axis=1)

test_rand=test1['New_ID'].str.split('_', n=1, expand=True)
test_rand.columns=['cid', 'label']
test_rand=test_rand[['cid', 'label']].astype(np.int64)
test_rand=pd.concat([test1['STD_SMILES'], test_rand], axis=1)

# %%
train_rand.head()
# Out:
#                                             STD_SMILES      cid  label
# 192  CC(=CCC1=C(C)C(=O)c2ccccc2C1=O)CCCC(C)CCCC(C)C...     4812      0
# 75        CN1CCC(Nc2ncc3ncnc(Nc4ccc(F)c(Cl)c4)c3n2)CC1  6918508      1
# 84   Cc1nnc(C(C)C)n1C1C[C@H]2CC[C@@H](C1)N2CC[C@H](...  3002977      1
# 361                          C#CCN(C)[C@H](C)Cc1ccccc1    26757      0
# 16   C[C@]12CC(=CO)C(=O)C[C@@H]1CC[C@@H]1[C@@H]2CC[...     9902      1

# %% [markdown]
# **For AVE bias analysis seggreate train and test into:**
#
# - Tp (train DILI positive); Tn (train DILI negative)
#
# - Vp (test/validation DILI positive); Vn (test/validation DILI negative)

# %%
Tp_rand=train_rand[train_rand['label']==1]
Tn_rand=train_rand[train_rand['label']==0]
Vp_rand=test_rand[test_rand['label']==1]
Vn_rand=test_rand[test_rand['label']==0]

# %%
print(Tp_rand.shape)
print(Tn_rand.shape)
print(Vp_rand.shape)
print(Vn_rand.shape)
# Out:
# (129, 3)
# (169, 3)
# (39, 3)
# (36, 3)

# %%
Tp_rand[['STD_SMILES', 'label']].to_csv('Tp_rand.smi', sep='\t', header=None, index=None)
Tn_rand[['STD_SMILES', 'label']].to_csv('Tn_rand.smi', sep='\t', header=None, index=None)
Vp_rand[['STD_SMILES', 'label']].to_csv('Vp_rand.smi', sep='\t', header=None, index=None)
Vn_rand[['STD_SMILES', 'label']].to_csv('Vn_rand.smi', sep='\t', header=None, index=None)

# %% [markdown]
# **Estimate Bias**

# %%
# !python analyze_AVE_bias.py
# Out:
# usage: analyze_AVE_bias.py
#        [-h]
#        [-fpType {DayLight,ECFP4,ECFP6,ECFP12,AP,MACCS}]
#        -activeMolsTraining
#        ACTIVEMOLSTRAINING
#        -inactiveMolsTraining
#        INACTIVEMOLSTRAINING
#        -activeMolsTesting
#        ACTIVEMOLSTESTING
#        -inactiveMolsTesting
#        INACTIVEMOLSTESTING
#        -outFile
#        OUTFILE
#        [-metric {jaccard,dice,euclidean}]
#        [-numWorkers NUMWORKERS]
# analyze_AVE_bias.py: error: the following arguments are required: -activeMolsTraining, -inactiveMolsTraining, -activeMolsTesting, -inactiveMolsTesting, -outFile

# %%
# !python analyze_AVE_bias.py -activeMolsTraining Tp_rand.smi -inactiveMolsTraining Tn_rand.smi -activeMolsTesting Vp_rand.smi -inactiveMolsTesting Vn_rand.smi -outFile result_rand.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 129 #InactTrain= 169 #ActTest= 39 #InactTest= 36 knn1= 0.6955128205128206 lr= 0.8561253561253562 rf= 0.868945868945869 svm= 0.8824786324786325 AA-AI= 0.10153846153846152 II-IA= 0.13055555555555554 (AA-AI)+(II-IA)= 0.23209401709401706

# %% [markdown]
# ### **Method 2: Molecular Clustering**

# %%
DILI[['STD_SMILES', 'New_ID']].to_csv('DILI_labelled.smi', sep='\t', index=None, header=None)

# %%
# !python mayachemtools/bin/RDKitClusterMolecules.py --infileParams "smilesColumn,1,smilesNameColumn,2,smilesDelimiter,tab,smilesTitleLine,auto,sanitize,yes" -i DILI_labelled.smi -o DILI_cluster.smi --overwrite

# %%
clus=pd.read_csv('DILI_cluster.smi', sep=' ')
clus.rename(columns={'Name':'New_ID'}, inplace=True)
clus
# Out:
#                                                 SMILES   New_ID  ClusterNumber
# 0                       CN(C)CCC(c1ccc(Cl)cc1)c1ccccn1   2725_0              1
# 1                      CN(C)CCOC(c1ccc(Cl)cc1)c1ccccn1   2564_0              1
# 2                       CN(C)CCC(c1ccc(Br)cc1)c1ccccn1   6834_0              1
# 3                  CN(C)CC[C@@H](c1ccc(Br)cc1)c1ccccn1  16960_0              1
# 4                  CN(C)CC[C@@H](c1ccc(Cl)cc1)c1ccccn1  33036_0              1
# ..                                                 ...      ...            ...
# 368     CC(=O)Oc1ccc(C(=C2CCCCC2)c2ccc(OC(C)=O)cc2)cc1   2898_1            315
# 369  Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...   2662_1            316
# 370  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...   2520_1            317
# 371                         CS(=O)(=O)OCCCCOS(C)(=O)=O   2478_1            318
# 372           O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12   3474_1            319
#
# [373 rows x 3 columns]

# %%
cluster_dist=clus['ClusterNumber'].value_counts().reset_index()
cluster_dist.columns=['ClusterNumber', 'Count']
cluster_dist
# Out:
#      ClusterNumber  Count
# 0                1      5
# 1                5      4
# 2                6      4
# 3                2      4
# 4                4      4
# ..             ...    ...
# 314            135      1
# 315            136      1
# 316            137      1
# 317            138      1
# 318            319      1
#
# [319 rows x 2 columns]

# %%
train2=clus.groupby('ClusterNumber').filter(lambda x: len(x)<2)
test2=clus.groupby('ClusterNumber').filter(lambda x: len(x)>=2)

# %%
print(train2.shape)
print(test2.shape)
# Out:
# (283, 3)
# (90, 3)

# %%
train2.head()
# Out:
#                                                SMILES      New_ID  \
# 66  CN1CC[C@]23c4c5ccc(O)c4O[C@H]2[C@@H](O)C=C[C@H...   5288826_0
# 91                         CC(Cc1ccccc1)N(C)Cc1ccccc1      2341_0
# 92                 C[Si](C)(C)O[Si](C)(C)O[Si](C)(C)C     24705_0
# 93                                   OC(O)C(Cl)(Cl)Cl      2707_0
# 94                        O=C1OC([C@@H](O)CO)C(O)=C1O  54678501_0
#
#     ClusterNumber
# 66             25
# 91             38
# 92             39
# 93             40
# 94             41

# %%
train_clus=train2['New_ID'].str.split('_', n=1, expand=True)
train_clus.columns=['cid', 'label']
train_clus=train_clus[['cid', 'label']].astype(np.int64)
train_clus=pd.concat([train2['SMILES'], train_clus], axis=1)

test_clus=test2['New_ID'].str.split('_', n=1, expand=True)
test_clus.columns=['cid', 'label']
test_clus=test_clus[['cid', 'label']].astype(np.int64)
test_clus=pd.concat([test2['SMILES'], test_clus], axis=1)

# %% [markdown]
# #####   **Seggregate:**
# - combined_train into Tp (DILI train positive) and Tn (DILI train negative)
#
# - combined_test into Vp (DILI test positive) and Vn (DILI test negative)

# %%
Tp_clus=train_clus[train_clus['label']==1]
Tn_clus=train_clus[train_clus['label']==0]
Vp_clus=test_clus[test_clus['label']==1]
Vn_clus=test_clus[test_clus['label']==0]

# %%
print(Tp_clus.shape)
print(Tn_clus.shape)
print(Vp_clus.shape)
print(Vn_clus.shape)
# Out:
# (139, 3)
# (144, 3)
# (29, 3)
# (61, 3)

# %%
Tp_clus[['SMILES', 'label']].to_csv('Tp_clus.smi', sep='\t', header=None, index=None)
Tn_clus[['SMILES', 'label']].to_csv('Tn_clus.smi', sep='\t', header=None, index=None)
Vp_clus[['SMILES', 'label']].to_csv('Vp_clus.smi', sep='\t', header=None, index=None)
Vn_clus[['SMILES', 'label']].to_csv('Vn_clus.smi', sep='\t', header=None, index=None)

# %% [markdown]
# #### **Estimate Bias**

# %%
# !python analyze_AVE_bias.py -activeMolsTraining Tp_clus.smi -inactiveMolsTraining Tn_clus.smi -activeMolsTesting Vp_clus.smi -inactiveMolsTesting Vn_clus.smi -outFile result_clus.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 139 #InactTrain= 144 #ActTest= 29 #InactTest= 61 knn1= 0.6873940079140757 lr= 0.8066704352741663 rf= 0.8247597512719049 svm= 0.8094968908988129 AA-AI= 0.07586206896551723 II-IA= 0.06852459016393442 (AA-AI)+(II-IA)= 0.14438665912945164

# %% [markdown]
# ###  **Method 3: Bemis-Murcko Scaffold-based Clustering**

# %%
mols = [Chem.MolFromSmiles(smi) for smi in DILI['STD_SMILES'] if smi is not None ]

# %%
scaffolds=[MurckoScaffold.GetScaffoldForMol(mol) for mol in mols if mol is not None]

# %%
murcko_smi=[Chem.MolToSmiles(mol) for mol in scaffolds if mol is not None]

# %%
murcko=pd.DataFrame(murcko_smi, columns=['Murcko_smi'])
murcko
# Out:
#                          Murcko_smi
# 0         c1ccc(Nc2ccnc3ccccc23)cc1
# 1
# 2         c1ccc(CCCCNCCc2ccccc2)cc1
# 3       c1ccc(-c2ccnn2-c2ccccc2)cc1
# 4    c1ccc(C(=C2CCCCC2)c2ccccc2)cc1
# ..                              ...
# 368
# 369                      O=C1C=CCO1
# 370
# 371
# 372          c1ccc(CCNCc2ccccc2)cc1
#
# [373 rows x 1 columns]

# %%
combined_murcko=pd.concat([DILI,murcko], axis=1)
combined_murcko.head()
# Out:
#     cid CompoundName Drug label-based annotation  \
# 0  3474    glafenine           Most DILI-concern
# 1  2478     busulfan           Most DILI-concern
# 2  2520    verapamil           Most DILI-concern
# 3  2662    celecoxib           Most DILI-concern
# 4  2898   cyclofenil           Most DILI-concern
#
#                                            isosmiles  label  \
# 0  C1=CC=C(C(=C1)C(=O)OCC(CO)O)NC2=C3C=CC(=CC3=NC...      1
# 1                         CS(=O)(=O)OCCCCOS(=O)(=O)C      1
# 2  CC(C)C(CCCN(C)CCC1=CC(=C(C=C1)OC)OC)(C#N)C2=CC...      1
# 3  CC1=CC=C(C=C1)C2=CC(=NN2C3=CC=C(C=C3)S(=O)(=O)...      1
# 4  CC(=O)OC1=CC=C(C=C1)C(=C2CCCCC2)C3=CC=C(C=C3)O...      1
#
#                                           STD_SMILES  New_ID  \
# 0           O=C(OCC(O)CO)c1ccccc1Nc1ccnc2cc(Cl)ccc12  3474_1
# 1                         CS(=O)(=O)OCCCCOS(C)(=O)=O  2478_1
# 2  COc1ccc(CCN(C)CCCC(C#N)(c2ccc(OC)c(OC)c2)C(C)C...  2520_1
# 3  Cc1ccc(-c2cc(C(F)(F)F)nn2-c2ccc(S(N)(=O)=O)cc2...  2662_1
# 4     CC(=O)Oc1ccc(C(=C2CCCCC2)c2ccc(OC(C)=O)cc2)cc1  2898_1
#
#                        Murcko_smi
# 0       c1ccc(Nc2ccnc3ccccc23)cc1
# 1
# 2       c1ccc(CCCCNCCc2ccccc2)cc1
# 3     c1ccc(-c2ccnn2-c2ccccc2)cc1
# 4  c1ccc(C(=C2CCCCC2)c2ccccc2)cc1

# %%
combined_murcko.to_csv('murcko.csv')

# %%
combined_murcko[['Murcko_smi','New_ID']].to_csv('murcko.smi', sep='\t', header=None, index=None)

# %% [markdown]
# **Clustering using MayaChem Tool**

# %%
# !python mayachemtools/bin/RDKitClusterMolecules.py --infileParams "smilesColumn,1,smilesNameColumn,2,smilesDelimiter,tab,smilesTitleLine,auto,sanitize,yes" -i murcko.smi -o murcko_cluster.smi --overwrite

# %%
murcko_clus=pd.read_csv('murcko_cluster.smi', sep=' ')
murcko_clus.rename(columns={'Name':'New_ID', 'SMILES':'Murcko_smi'}, inplace=True)
murcko_clus
# Out:
#                           Murcko_smi     New_ID  ClusterNumber
# 0                           c1ccccc1  5281081_0              1
# 1                           c1ccccc1     4260_1              1
# 2                           c1ccccc1     5354_1              1
# 3                           c1ccccc1    15250_1              1
# 4                           c1ccccc1     3397_1              1
# ..                               ...        ...            ...
# 334         c1ccc(CN2CCc3sccc3C2)cc1     5472_1            184
# 335         C1=Cc2ccccc2C1=Cc1ccccc1     5352_1            185
# 336  O=C1C[C@H](c2ccccc2)Sc2ccccc2N1    39186_1            186
# 337   C1CCC(C(CC2CCCCN2)C2CCCCC2)CC1     4746_1            187
# 338         c1ccc2c3c([nH]c2c1)COCC3     3308_1            188
#
# [339 rows x 3 columns]

# %%
murcko_cluster_dist=murcko_clus['ClusterNumber'].value_counts().reset_index()
murcko_cluster_dist.columns=['ClusterNumber', 'Count']
murcko_cluster_dist
# Out:
#      ClusterNumber  Count
# 0                1     46
# 1                2     24
# 2                3     11
# 3                5      7
# 4                6      7
# ..             ...    ...
# 183             92      1
# 184             93      1
# 185             94      1
# 186             96      1
# 187            188      1
#
# [188 rows x 2 columns]

# %%
combined_murcko_clus=pd.merge(murcko_clus,combined_murcko[['New_ID','CompoundName', 'Drug label-based annotation',	'STD_SMILES','isosmiles', 'label']], on='New_ID')
print(combined_murcko_clus.shape)
combined_murcko_clus.head()
# Out:
# (339, 8)
#   Murcko_smi     New_ID  ClusterNumber CompoundName  \
# 0   c1ccccc1  5281081_0              1   entacapone
# 1   c1ccccc1     4260_1              1   moxisylyte
# 2   c1ccccc1     5354_1              1   suloctidil
# 3   c1ccccc1    15250_1              1     ibufenac
# 4   c1ccccc1     3397_1              1    flutamide
#
#   Drug label-based annotation  \
# 0             no DILI-concern
# 1           Most DILI-concern
# 2           Most DILI-concern
# 3           Most DILI-concern
# 4           Most DILI-concern
#
#                                           STD_SMILES  \
# 0  CCN(CC)C(=O)/C(C#N)=C/c1cc(O)c(O)c([N+](=O)[O-...
# 1                  CC(=O)Oc1cc(C(C)C)c(OCCN(C)C)cc1C
# 2                  CCCCCCCCNC(C)C(O)c1ccc(SC(C)C)cc1
# 3                            CC(C)Cc1ccc(CC(=O)O)cc1
# 4        CC(C)C(=O)Nc1ccc([N+](=O)[O-])c(C(F)(F)F)c1
#
#                                            isosmiles  label
# 0  CCN(CC)C(=O)/C(=C/C1=CC(=C(C(=C1)O)O)[N+](=O)[...      0
# 1               CC1=CC(=C(C=C1OC(=O)C)C(C)C)OCCN(C)C      1
# 2               CCCCCCCCNC(C)C(C1=CC=C(C=C1)SC(C)C)O      1
# 3                         CC(C)CC1=CC=C(C=C1)CC(=O)O      1
# 4     CC(C)C(=O)NC1=CC(=C(C=C1)[N+](=O)[O-])C(F)(F)F      1

# %%
combined_murcko_clus.to_csv('murcko_clus.csv', sep='\t', index=None)

# %%
train3_murcko=combined_murcko_clus.groupby('ClusterNumber').filter(lambda x: len(x)>=2)
test3_murcko=combined_murcko_clus.groupby('ClusterNumber').filter(lambda x: len(x)<2)

# %%
print(train3_murcko.shape)
print(test3_murcko.shape)
# Out:
# (195, 8)
# (144, 8)

# %%
Tp_murcko=train3_murcko[train3_murcko['label']==1]
Tn_murcko=train3_murcko[train3_murcko['label']==0]
Vp_murcko=test3_murcko[test3_murcko['label']==1]
Vn_murcko=test3_murcko[test3_murcko['label']==0]

# %%
print(Tp_murcko.shape)
print(Tn_murcko.shape)
print(Vp_murcko.shape)
print(Vn_murcko.shape)
# Out:
# (77, 8)
# (118, 8)
# (85, 8)
# (59, 8)

# %%
Tp_murcko[['STD_SMILES', 'label']].to_csv('Tp_murcko.smi', sep='\t', header=None, index=None)
Tn_murcko[['STD_SMILES', 'label']].to_csv('Tn_murcko.smi', sep='\t', header=None, index=None)
Vp_murcko[['STD_SMILES', 'label']].to_csv('Vp_murcko.smi', sep='\t', header=None, index=None)
Vn_murcko[['STD_SMILES', 'label']].to_csv('Vn_murcko.smi', sep='\t', header=None, index=None)

# %%
# !python analyze_AVE_bias.py -activeMolsTraining Tp_murcko.smi -inactiveMolsTraining Tn_murcko.smi -activeMolsTesting Vp_murcko.smi -inactiveMolsTesting Vn_murcko.smi -outFile result_murcko.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 77 #InactTrain= 118 #ActTest= 85 #InactTest= 59 knn1= 0.6010967098703888 lr= 0.6739780658025922 rf= 0.6795613160518444 svm= 0.6532402791625125 AA-AI= 0.021176470588235297 II-IA= 0.03423728813559318 (AA-AI)+(II-IA)= 0.05541375872382848

# %% [markdown]
# ### **Bias Comaprison**

# %%
Bias = pd.DataFrame({'Data':['Random Split','Molecular Clustering','Scaffold-based Clustering'], 'Bias(AVE)':[0.2321, 0.1444, 0.0554]})
Bias
# Out:
#                         Data  Bias(AVE)
# 0               Random Split     0.2321
# 1       Molecular Clustering     0.1444
# 2  Scaffold-based Clustering     0.0554

# %% [markdown]
# ## **Remove Bias**

# %% [markdown]
# ### **Method 1: Train/Test Random Split**

# %%
# !python remove_AVE_bias.py
# Out:
# usage: remove_AVE_bias.py
#        [-h]
#        [-fpType {DayLight,ECFP4,ECFP6,ECFP12,AP,MACCS}]
#        -activeMols
#        ACTIVEMOLS
#        -inactiveMols
#        INACTIVEMOLS
#        [-trainingToValidationRatio TRAININGTOVALIDATIONRATIO]
#        [-outDir OUTDIR]
#        [-numWorkers NUMWORKERS]
#        [-statePickleFile STATEPICKLEFILE]
#        [-maxIter MAXITER]
#        [-maxNumMols MAXNUMMOLS]
# remove_AVE_bias.py: error: the following arguments are required: -activeMols, -inactiveMols

# %%
active_rand=pd.concat([Tp_rand,Vp_rand], axis=0)
inactive_rand=pd.concat([Tn_rand,Vn_rand], axis=0)

# %%
active_rand[['STD_SMILES', 'label']].to_csv('active_rand.smi', sep='\t', header=None, index=None)
inactive_rand[['STD_SMILES', 'label']].to_csv('inactive_rand.smi', sep='\t', header=None, index=None)

# %%
# !python remove_AVE_bias.py -activeMols active_rand.smi -inactiveMols inactive_rand.smi -numWorkers 4 -maxIter 1000
# Out:
# ('read', 168, 'actives and', 205, 'inactives')
# calc aa_D_ref
# calc ii_D_ref
# calc ai_D_ref
# done
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 1, 'fullPopObj=', 0.179, 'topPopObj=', 0.179, 'finalPopObj=', 0.179, 'minObj=', 99999)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 2, 'fullPopObj=', 0.176, 'topPopObj=', 0.176, 'finalPopObj=', 0.157, 'minObj=', 0.179)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 3, 'fullPopObj=', 0.172, 'topPopObj=', 0.172, 'finalPopObj=', 0.163, 'minObj=', 0.157)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 4, 'fullPopObj=', 0.169, 'topPopObj=', 0.169, 'finalPopObj=', 0.152, 'minObj=', 0.157)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 5, 'fullPopObj=', 0.164, 'topPopObj=', 0.164, 'finalPopObj=', 0.159, 'minObj=', 0.152)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 6, 'fullPopObj=', 0.165, 'topPopObj=', 0.165, 'finalPopObj=', 0.144, 'minObj=', 0.152)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 7, 'fullPopObj=', 0.163, 'topPopObj=', 0.163, 'finalPopObj=', 0.153, 'minObj=', 0.144)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 8, 'fullPopObj=', 0.16, 'topPopObj=', 0.16, 'finalPopObj=', 0.145, 'minObj=', 0.144)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 9, 'fullPopObj=', 0.159, 'topPopObj=', 0.159, 'finalPopObj=', 0.143, 'minObj=', 0.144)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 10, 'fullPopObj=', 0.156, 'topPopObj=', 0.156, 'finalPopObj=', 0.131, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 11, 'fullPopObj=', 0.153, 'topPopObj=', 0.153, 'finalPopObj=', 0.138, 'minObj=', 0.131)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 12, 'fullPopObj=', 0.152, 'topPopObj=', 0.152, 'finalPopObj=', 0.132, 'minObj=', 0.131)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 13, 'fullPopObj=', 0.146, 'topPopObj=', 0.146, 'finalPopObj=', 0.13, 'minObj=', 0.131)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 14, 'fullPopObj=', 0.145, 'topPopObj=', 0.145, 'finalPopObj=', 0.129, 'minObj=', 0.13)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 15, 'fullPopObj=', 0.14, 'topPopObj=', 0.14, 'finalPopObj=', 0.114, 'minObj=', 0.129)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 16, 'fullPopObj=', 0.137, 'topPopObj=', 0.137, 'finalPopObj=', 0.12, 'minObj=', 0.114)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 17, 'fullPopObj=', 0.13, 'topPopObj=', 0.13, 'finalPopObj=', 0.105, 'minObj=', 0.114)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 18, 'fullPopObj=', 0.128, 'topPopObj=', 0.128, 'finalPopObj=', 0.105, 'minObj=', 0.105)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 19, 'fullPopObj=', 0.127, 'topPopObj=', 0.127, 'finalPopObj=', 0.099, 'minObj=', 0.105)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 20, 'fullPopObj=', 0.122, 'topPopObj=', 0.122, 'finalPopObj=', 0.096, 'minObj=', 0.099)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 21, 'fullPopObj=', 0.113, 'topPopObj=', 0.113, 'finalPopObj=', 0.076, 'minObj=', 0.096)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 22, 'fullPopObj=', 0.113, 'topPopObj=', 0.113, 'finalPopObj=', 0.097, 'minObj=', 0.076)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 23, 'fullPopObj=', 0.101, 'topPopObj=', 0.101, 'finalPopObj=', 0.076, 'minObj=', 0.076)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 24, 'fullPopObj=', 0.102, 'topPopObj=', 0.102, 'finalPopObj=', 0.087, 'minObj=', 0.076)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 25, 'fullPopObj=', 0.096, 'topPopObj=', 0.096, 'finalPopObj=', 0.081, 'minObj=', 0.076)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 26, 'fullPopObj=', 0.09, 'topPopObj=', 0.09, 'finalPopObj=', 0.074, 'minObj=', 0.076)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 27, 'fullPopObj=', 0.091, 'topPopObj=', 0.091, 'finalPopObj=', 0.064, 'minObj=', 0.074)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 28, 'fullPopObj=', 0.085, 'topPopObj=', 0.085, 'finalPopObj=', 0.057, 'minObj=', 0.064)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 29, 'fullPopObj=', 0.078, 'topPopObj=', 0.078, 'finalPopObj=', 0.048, 'minObj=', 0.057)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 30, 'fullPopObj=', 0.076, 'topPopObj=', 0.076, 'finalPopObj=', 0.052, 'minObj=', 0.048)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 31, 'fullPopObj=', 0.07, 'topPopObj=', 0.07, 'finalPopObj=', 0.044, 'minObj=', 0.048)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 32, 'fullPopObj=', 0.065, 'topPopObj=', 0.065, 'finalPopObj=', 0.038, 'minObj=', 0.044)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 33, 'fullPopObj=', 0.065, 'topPopObj=', 0.065, 'finalPopObj=', 0.047, 'minObj=', 0.038)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 34, 'fullPopObj=', 0.061, 'topPopObj=', 0.061, 'finalPopObj=', 0.047, 'minObj=', 0.038)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 35, 'fullPopObj=', 0.061, 'topPopObj=', 0.061, 'finalPopObj=', 0.044, 'minObj=', 0.038)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 36, 'fullPopObj=', 0.063, 'topPopObj=', 0.063, 'finalPopObj=', 0.04, 'minObj=', 0.038)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 37, 'fullPopObj=', 0.066, 'topPopObj=', 0.066, 'finalPopObj=', 0.036, 'minObj=', 0.038)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 38, 'fullPopObj=', 0.061, 'topPopObj=', 0.061, 'finalPopObj=', 0.037, 'minObj=', 0.036)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 39, 'fullPopObj=', 0.062, 'topPopObj=', 0.062, 'finalPopObj=', 0.039, 'minObj=', 0.036)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 40, 'fullPopObj=', 0.058, 'topPopObj=', 0.058, 'finalPopObj=', 0.031, 'minObj=', 0.036)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 41, 'fullPopObj=', 0.053, 'topPopObj=', 0.053, 'finalPopObj=', 0.036, 'minObj=', 0.031)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 42, 'fullPopObj=', 0.047, 'topPopObj=', 0.047, 'finalPopObj=', 0.025, 'minObj=', 0.031)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 43, 'fullPopObj=', 0.042, 'topPopObj=', 0.042, 'finalPopObj=', 0.023, 'minObj=', 0.025)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 44, 'fullPopObj=', 0.041, 'topPopObj=', 0.041, 'finalPopObj=', 0.023, 'minObj=', 0.023)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 45, 'fullPopObj=', 0.037, 'topPopObj=', 0.037, 'finalPopObj=', 0.02, 'minObj=', 0.023)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 46, 'fullPopObj=', 0.037, 'topPopObj=', 0.037, 'finalPopObj=', 0.017, 'minObj=', 0.02)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 47, 'fullPopObj=', 0.035, 'topPopObj=', 0.035, 'finalPopObj=', 0.023, 'minObj=', 0.017)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 48, 'fullPopObj=', 0.031, 'topPopObj=', 0.031, 'finalPopObj=', 0.017, 'minObj=', 0.017)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 49, 'fullPopObj=', 0.027, 'topPopObj=', 0.027, 'finalPopObj=', 0.013, 'minObj=', 0.017)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 50, 'fullPopObj=', 0.026, 'topPopObj=', 0.026, 'finalPopObj=', 0.004, 'minObj=', 0.013)
# Done. Total running time: 87.592 sec

# %% [markdown]
# #### ***Re-estimate Bias***

# %%
# !python analyze_AVE_bias.py -activeMolsTraining actives.T.smi -inactiveMolsTraining inactives.T.smi -activeMolsTesting actives.V.smi -inactiveMolsTesting inactives.V.smi -outFile result_rand.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 122 #InactTrain= 149 #ActTest= 18 #InactTest= 26 knn1= 0.423076923076923 lr= 0.6025641025641025 rf= 0.6228632478632479 svm= 0.6324786324786325 AA-AI= 0.0044444444444444176 II-IA= -0.0007692307692307443 (AA-AI)+(II-IA)= 0.0036752136752136733

# %% [markdown]
# #### ***New Train and Test data from AVE output***
#
#
# *  train = actives.T.smi + inactives.T.smi
# *  test = actives.V.smi + inactives.V.smi

# %%
# Train data
activesT_rand=pd.read_csv('actives.T.smi', sep=' ', header=None)
activesT_rand.columns=['Smiles', 'label']

inactivesT_rand=pd.read_csv('inactives.T.smi', sep=' ', header=None)
inactivesT_rand.columns=['Smiles', 'label']

train_data_rand=pd.concat([activesT_rand, inactivesT_rand], axis=0)
train_data_rand=train_data_rand.reset_index(drop=True)
print('Train_rand shape:', train_data_rand.shape)
train_data_rand.to_csv('train_data_rand.csv', sep='\t', index=None)

# Test data
activesV_rand=pd.read_csv('actives.V.smi', sep=' ', header=None)
activesV_rand.columns=['Smiles', 'label']

inactivesV_rand=pd.read_csv('inactives.V.smi', sep=' ', header=None)
inactivesV_rand.columns=['Smiles', 'label']

test_data_rand=pd.concat([activesV_rand, inactivesV_rand], axis=0)
test_data_rand=test_data_rand.reset_index(drop=True)
print('Test_rand shape:', test_data_rand.shape)
test_data_rand.to_csv('test_data_rand.csv', sep='\t', index=None)
# Out:
# Train_rand shape: (271, 2)
# Test_rand shape: (44, 2)

# %% [markdown]
# ### **Method 2: Molecular Clustering**

# %%
active_clus=pd.concat([Tp_clus,Vp_clus], axis=0)
inactive_clus=pd.concat([Tn_clus,Vn_clus], axis=0)

# %%
active_clus[['SMILES', 'label']].to_csv('active_clus.smi', sep='\t', header=None, index=None)
inactive_clus[['SMILES', 'label']].to_csv('inactive_clus.smi', sep='\t', header=None, index=None)

# %%
# !python remove_AVE_bias.py -activeMols active_clus.smi -inactiveMols inactive_clus.smi -numWorkers 4 -maxIter 1000
# Out:
# ('read', 168, 'actives and', 205, 'inactives')
# calc aa_D_ref
# calc ii_D_ref
# calc ai_D_ref
# done
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 1, 'fullPopObj=', 0.159, 'topPopObj=', 0.159, 'finalPopObj=', 0.159, 'minObj=', 99999)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 2, 'fullPopObj=', 0.157, 'topPopObj=', 0.157, 'finalPopObj=', 0.15, 'minObj=', 0.159)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 3, 'fullPopObj=', 0.151, 'topPopObj=', 0.151, 'finalPopObj=', 0.137, 'minObj=', 0.15)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 4, 'fullPopObj=', 0.15, 'topPopObj=', 0.15, 'finalPopObj=', 0.143, 'minObj=', 0.137)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 5, 'fullPopObj=', 0.146, 'topPopObj=', 0.146, 'finalPopObj=', 0.128, 'minObj=', 0.137)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 6, 'fullPopObj=', 0.143, 'topPopObj=', 0.143, 'finalPopObj=', 0.132, 'minObj=', 0.128)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 7, 'fullPopObj=', 0.139, 'topPopObj=', 0.139, 'finalPopObj=', 0.13, 'minObj=', 0.128)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 8, 'fullPopObj=', 0.136, 'topPopObj=', 0.136, 'finalPopObj=', 0.123, 'minObj=', 0.128)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 9, 'fullPopObj=', 0.131, 'topPopObj=', 0.131, 'finalPopObj=', 0.118, 'minObj=', 0.123)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 10, 'fullPopObj=', 0.13, 'topPopObj=', 0.13, 'finalPopObj=', 0.11, 'minObj=', 0.118)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 11, 'fullPopObj=', 0.128, 'topPopObj=', 0.128, 'finalPopObj=', 0.112, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 12, 'fullPopObj=', 0.124, 'topPopObj=', 0.124, 'finalPopObj=', 0.113, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 13, 'fullPopObj=', 0.127, 'topPopObj=', 0.127, 'finalPopObj=', 0.113, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 14, 'fullPopObj=', 0.124, 'topPopObj=', 0.124, 'finalPopObj=', 0.112, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 15, 'fullPopObj=', 0.12, 'topPopObj=', 0.12, 'finalPopObj=', 0.107, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 16, 'fullPopObj=', 0.117, 'topPopObj=', 0.117, 'finalPopObj=', 0.102, 'minObj=', 0.107)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 17, 'fullPopObj=', 0.114, 'topPopObj=', 0.114, 'finalPopObj=', 0.093, 'minObj=', 0.102)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 18, 'fullPopObj=', 0.119, 'topPopObj=', 0.119, 'finalPopObj=', 0.092, 'minObj=', 0.093)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 19, 'fullPopObj=', 0.115, 'topPopObj=', 0.115, 'finalPopObj=', 0.103, 'minObj=', 0.092)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 20, 'fullPopObj=', 0.113, 'topPopObj=', 0.113, 'finalPopObj=', 0.094, 'minObj=', 0.092)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 21, 'fullPopObj=', 0.112, 'topPopObj=', 0.112, 'finalPopObj=', 0.093, 'minObj=', 0.092)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 22, 'fullPopObj=', 0.111, 'topPopObj=', 0.111, 'finalPopObj=', 0.091, 'minObj=', 0.092)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 23, 'fullPopObj=', 0.11, 'topPopObj=', 0.11, 'finalPopObj=', 0.08, 'minObj=', 0.091)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 24, 'fullPopObj=', 0.115, 'topPopObj=', 0.115, 'finalPopObj=', 0.097, 'minObj=', 0.08)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 25, 'fullPopObj=', 0.11, 'topPopObj=', 0.11, 'finalPopObj=', 0.085, 'minObj=', 0.08)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 26, 'fullPopObj=', 0.107, 'topPopObj=', 0.107, 'finalPopObj=', 0.078, 'minObj=', 0.08)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 27, 'fullPopObj=', 0.103, 'topPopObj=', 0.103, 'finalPopObj=', 0.075, 'minObj=', 0.078)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 28, 'fullPopObj=', 0.099, 'topPopObj=', 0.099, 'finalPopObj=', 0.077, 'minObj=', 0.075)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 29, 'fullPopObj=', 0.091, 'topPopObj=', 0.091, 'finalPopObj=', 0.071, 'minObj=', 0.075)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 30, 'fullPopObj=', 0.088, 'topPopObj=', 0.088, 'finalPopObj=', 0.07, 'minObj=', 0.071)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 31, 'fullPopObj=', 0.085, 'topPopObj=', 0.085, 'finalPopObj=', 0.063, 'minObj=', 0.07)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 32, 'fullPopObj=', 0.079, 'topPopObj=', 0.079, 'finalPopObj=', 0.054, 'minObj=', 0.063)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 33, 'fullPopObj=', 0.08, 'topPopObj=', 0.08, 'finalPopObj=', 0.061, 'minObj=', 0.054)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 34, 'fullPopObj=', 0.078, 'topPopObj=', 0.078, 'finalPopObj=', 0.057, 'minObj=', 0.054)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 35, 'fullPopObj=', 0.075, 'topPopObj=', 0.075, 'finalPopObj=', 0.059, 'minObj=', 0.054)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 36, 'fullPopObj=', 0.069, 'topPopObj=', 0.069, 'finalPopObj=', 0.039, 'minObj=', 0.054)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 37, 'fullPopObj=', 0.07, 'topPopObj=', 0.07, 'finalPopObj=', 0.044, 'minObj=', 0.039)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 38, 'fullPopObj=', 0.066, 'topPopObj=', 0.066, 'finalPopObj=', 0.047, 'minObj=', 0.039)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 39, 'fullPopObj=', 0.056, 'topPopObj=', 0.056, 'finalPopObj=', 0.042, 'minObj=', 0.039)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 40, 'fullPopObj=', 0.054, 'topPopObj=', 0.054, 'finalPopObj=', 0.028, 'minObj=', 0.039)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 41, 'fullPopObj=', 0.053, 'topPopObj=', 0.053, 'finalPopObj=', 0.037, 'minObj=', 0.028)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 42, 'fullPopObj=', 0.053, 'topPopObj=', 0.053, 'finalPopObj=', 0.034, 'minObj=', 0.028)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 43, 'fullPopObj=', 0.048, 'topPopObj=', 0.048, 'finalPopObj=', 0.03, 'minObj=', 0.028)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 44, 'fullPopObj=', 0.047, 'topPopObj=', 0.047, 'finalPopObj=', 0.028, 'minObj=', 0.028)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 45, 'fullPopObj=', 0.037, 'topPopObj=', 0.037, 'finalPopObj=', 0.016, 'minObj=', 0.028)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 46, 'fullPopObj=', 0.036, 'topPopObj=', 0.036, 'finalPopObj=', 0.013, 'minObj=', 0.016)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 47, 'fullPopObj=', 0.034, 'topPopObj=', 0.034, 'finalPopObj=', 0.015, 'minObj=', 0.013)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 48, 'fullPopObj=', 0.028, 'topPopObj=', 0.028, 'finalPopObj=', 0.006, 'minObj=', 0.013)
# Done. Total running time: 72.893 sec

# %% [markdown]
# #### ***Re-estimate Bias***

# %%
# !python analyze_AVE_bias.py -activeMolsTraining actives.T.smi -inactiveMolsTraining inactives.T.smi -activeMolsTesting actives.V.smi -inactiveMolsTesting inactives.V.smi -outFile result_clus.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 125 #InactTrain= 152 #ActTest= 21 #InactTest= 25 knn1= 0.680952380952381 lr= 0.6628571428571428 rf= 0.5752380952380952 svm= 0.6247619047619047 AA-AI= 0.006666666666666654 II-IA= -0.0007999999999999674 (AA-AI)+(II-IA)= 0.005866666666666687

# %% [markdown]
# #### ***New Train and Test data from AVE output***

# %%
# Train data
activesT_clus=pd.read_csv('actives.T.smi', sep=' ', header=None)
activesT_clus.columns=['Smiles', 'label']

inactivesT_clus=pd.read_csv('inactives.T.smi', sep=' ', header=None)
inactivesT_clus.columns=['Smiles', 'label']

train_data_clus=pd.concat([activesT_clus, inactivesT_clus], axis=0)
train_data_clus=train_data_clus.reset_index(drop=True)
print('Train_clus shape:', train_data_clus.shape)
train_data_rand.to_csv('train_data_rand.csv', sep='\t', index=None)

# Test data
activesV_clus=pd.read_csv('actives.V.smi', sep=' ', header=None)
activesV_clus.columns=['Smiles', 'label']

inactivesV_clus=pd.read_csv('inactives.V.smi', sep=' ', header=None)
inactivesV_clus.columns=['Smiles', 'label']

test_data_clus=pd.concat([activesV_clus, inactivesV_clus], axis=0)
test_data_clus=test_data_clus.reset_index(drop=True)
print('Test_clus shape:', test_data_clus.shape)
test_data_clus.to_csv('test_data_clus.csv', sep='\t', index=None)
# Out:
# Train_clus shape: (277, 2)
# Test_clus shape: (46, 2)

# %% [markdown]
# ### **Method 3: Scaffold-based Clustering**

# %%
active_murcko=pd.concat([Tp_murcko,Vp_murcko], axis=0)
inactive_murcko=pd.concat([Tn_murcko,Vn_murcko], axis=0)

# %%
active_murcko[['STD_SMILES', 'label']].to_csv('active_murcko.smi', sep='\t', header=None, index=None)
inactive_murcko[['STD_SMILES', 'label']].to_csv('inactive_murcko.smi', sep='\t', header=None, index=None)

# %%
# !python remove_AVE_bias.py -activeMols active_murcko.smi -inactiveMols inactive_murcko.smi -numWorkers 4 -maxIter 1000
# Out:
# ('read', 162, 'actives and', 177, 'inactives')
# calc aa_D_ref
# calc ii_D_ref
# calc ai_D_ref
# done
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 1, 'fullPopObj=', 0.249, 'topPopObj=', 0.249, 'finalPopObj=', 0.249, 'minObj=', 99999)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 2, 'fullPopObj=', 0.246, 'topPopObj=', 0.246, 'finalPopObj=', 0.236, 'minObj=', 0.249)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 3, 'fullPopObj=', 0.238, 'topPopObj=', 0.238, 'finalPopObj=', 0.227, 'minObj=', 0.236)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 4, 'fullPopObj=', 0.235, 'topPopObj=', 0.235, 'finalPopObj=', 0.226, 'minObj=', 0.227)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 5, 'fullPopObj=', 0.231, 'topPopObj=', 0.231, 'finalPopObj=', 0.219, 'minObj=', 0.226)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 6, 'fullPopObj=', 0.225, 'topPopObj=', 0.225, 'finalPopObj=', 0.202, 'minObj=', 0.219)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 7, 'fullPopObj=', 0.226, 'topPopObj=', 0.226, 'finalPopObj=', 0.205, 'minObj=', 0.202)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 8, 'fullPopObj=', 0.225, 'topPopObj=', 0.225, 'finalPopObj=', 0.216, 'minObj=', 0.202)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 9, 'fullPopObj=', 0.218, 'topPopObj=', 0.218, 'finalPopObj=', 0.205, 'minObj=', 0.202)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 10, 'fullPopObj=', 0.211, 'topPopObj=', 0.211, 'finalPopObj=', 0.191, 'minObj=', 0.202)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 11, 'fullPopObj=', 0.21, 'topPopObj=', 0.21, 'finalPopObj=', 0.196, 'minObj=', 0.191)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 12, 'fullPopObj=', 0.205, 'topPopObj=', 0.205, 'finalPopObj=', 0.194, 'minObj=', 0.191)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 13, 'fullPopObj=', 0.201, 'topPopObj=', 0.201, 'finalPopObj=', 0.183, 'minObj=', 0.191)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 14, 'fullPopObj=', 0.198, 'topPopObj=', 0.198, 'finalPopObj=', 0.157, 'minObj=', 0.183)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 15, 'fullPopObj=', 0.191, 'topPopObj=', 0.191, 'finalPopObj=', 0.156, 'minObj=', 0.157)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 16, 'fullPopObj=', 0.189, 'topPopObj=', 0.189, 'finalPopObj=', 0.167, 'minObj=', 0.156)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 17, 'fullPopObj=', 0.185, 'topPopObj=', 0.185, 'finalPopObj=', 0.168, 'minObj=', 0.156)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 18, 'fullPopObj=', 0.183, 'topPopObj=', 0.183, 'finalPopObj=', 0.166, 'minObj=', 0.156)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 19, 'fullPopObj=', 0.18, 'topPopObj=', 0.18, 'finalPopObj=', 0.146, 'minObj=', 0.156)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 20, 'fullPopObj=', 0.181, 'topPopObj=', 0.181, 'finalPopObj=', 0.143, 'minObj=', 0.146)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 21, 'fullPopObj=', 0.175, 'topPopObj=', 0.175, 'finalPopObj=', 0.16, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 22, 'fullPopObj=', 0.174, 'topPopObj=', 0.174, 'finalPopObj=', 0.149, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 23, 'fullPopObj=', 0.169, 'topPopObj=', 0.169, 'finalPopObj=', 0.144, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 24, 'fullPopObj=', 0.164, 'topPopObj=', 0.164, 'finalPopObj=', 0.146, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 25, 'fullPopObj=', 0.163, 'topPopObj=', 0.163, 'finalPopObj=', 0.143, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 26, 'fullPopObj=', 0.16, 'topPopObj=', 0.16, 'finalPopObj=', 0.126, 'minObj=', 0.143)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 27, 'fullPopObj=', 0.155, 'topPopObj=', 0.155, 'finalPopObj=', 0.114, 'minObj=', 0.126)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 28, 'fullPopObj=', 0.156, 'topPopObj=', 0.156, 'finalPopObj=', 0.116, 'minObj=', 0.114)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 29, 'fullPopObj=', 0.155, 'topPopObj=', 0.155, 'finalPopObj=', 0.111, 'minObj=', 0.114)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 30, 'fullPopObj=', 0.157, 'topPopObj=', 0.157, 'finalPopObj=', 0.135, 'minObj=', 0.111)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 31, 'fullPopObj=', 0.153, 'topPopObj=', 0.153, 'finalPopObj=', 0.134, 'minObj=', 0.111)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 32, 'fullPopObj=', 0.148, 'topPopObj=', 0.148, 'finalPopObj=', 0.11, 'minObj=', 0.111)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 33, 'fullPopObj=', 0.151, 'topPopObj=', 0.151, 'finalPopObj=', 0.119, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 34, 'fullPopObj=', 0.148, 'topPopObj=', 0.148, 'finalPopObj=', 0.115, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 35, 'fullPopObj=', 0.143, 'topPopObj=', 0.143, 'finalPopObj=', 0.12, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 36, 'fullPopObj=', 0.143, 'topPopObj=', 0.143, 'finalPopObj=', 0.126, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 37, 'fullPopObj=', 0.132, 'topPopObj=', 0.132, 'finalPopObj=', 0.1, 'minObj=', 0.11)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 38, 'fullPopObj=', 0.132, 'topPopObj=', 0.132, 'finalPopObj=', 0.103, 'minObj=', 0.1)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 39, 'fullPopObj=', 0.119, 'topPopObj=', 0.119, 'finalPopObj=', 0.09, 'minObj=', 0.1)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 40, 'fullPopObj=', 0.114, 'topPopObj=', 0.114, 'finalPopObj=', 0.09, 'minObj=', 0.09)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 41, 'fullPopObj=', 0.111, 'topPopObj=', 0.111, 'finalPopObj=', 0.09, 'minObj=', 0.09)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 42, 'fullPopObj=', 0.11, 'topPopObj=', 0.11, 'finalPopObj=', 0.09, 'minObj=', 0.09)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 43, 'fullPopObj=', 0.109, 'topPopObj=', 0.109, 'finalPopObj=', 0.085, 'minObj=', 0.09)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 44, 'fullPopObj=', 0.098, 'topPopObj=', 0.098, 'finalPopObj=', 0.077, 'minObj=', 0.085)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 45, 'fullPopObj=', 0.098, 'topPopObj=', 0.098, 'finalPopObj=', 0.068, 'minObj=', 0.077)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 46, 'fullPopObj=', 0.096, 'topPopObj=', 0.096, 'finalPopObj=', 0.06, 'minObj=', 0.068)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 47, 'fullPopObj=', 0.097, 'topPopObj=', 0.097, 'finalPopObj=', 0.051, 'minObj=', 0.06)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 48, 'fullPopObj=', 0.092, 'topPopObj=', 0.092, 'finalPopObj=', 0.064, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 49, 'fullPopObj=', 0.088, 'topPopObj=', 0.088, 'finalPopObj=', 0.054, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 50, 'fullPopObj=', 0.09, 'topPopObj=', 0.09, 'finalPopObj=', 0.067, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 51, 'fullPopObj=', 0.087, 'topPopObj=', 0.087, 'finalPopObj=', 0.058, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 52, 'fullPopObj=', 0.076, 'topPopObj=', 0.076, 'finalPopObj=', 0.051, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 53, 'fullPopObj=', 0.073, 'topPopObj=', 0.073, 'finalPopObj=', 0.051, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 54, 'fullPopObj=', 0.072, 'topPopObj=', 0.072, 'finalPopObj=', 0.036, 'minObj=', 0.051)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 55, 'fullPopObj=', 0.065, 'topPopObj=', 0.065, 'finalPopObj=', 0.031, 'minObj=', 0.036)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 56, 'fullPopObj=', 0.063, 'topPopObj=', 0.063, 'finalPopObj=', 0.038, 'minObj=', 0.031)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 57, 'fullPopObj=', 0.061, 'topPopObj=', 0.061, 'finalPopObj=', 0.039, 'minObj=', 0.031)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 58, 'fullPopObj=', 0.054, 'topPopObj=', 0.054, 'finalPopObj=', 0.022, 'minObj=', 0.031)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 59, 'fullPopObj=', 0.047, 'topPopObj=', 0.047, 'finalPopObj=', 0.011, 'minObj=', 0.022)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 60, 'fullPopObj=', 0.045, 'topPopObj=', 0.045, 'finalPopObj=', 0.023, 'minObj=', 0.011)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 61, 'fullPopObj=', 0.038, 'topPopObj=', 0.038, 'finalPopObj=', 0.011, 'minObj=', 0.011)
# breed
# calculate objectives for the population
# remove similar sets
# ('removing', 20, 'similar sets')
# ('population size after similarity filter: ', 20)
# select the next generation
# ('iter=', 62, 'fullPopObj=', 0.03, 'topPopObj=', 0.03, 'finalPopObj=', 0.002, 'minObj=', 0.011)
# Done. Total running time: 81.816 sec

# %% [markdown]
# #### ***Re-estimate Bias***

# %%
# !python analyze_AVE_bias.py -activeMolsTraining actives.T.smi -inactiveMolsTraining inactives.T.smi -activeMolsTesting actives.V.smi -inactiveMolsTesting inactives.V.smi -outFile result_murcko.txt -numWorkers 4
# Out:
# init 4 workers
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/pairwise.py:2025: DataConversionWarning: Data was converted to boolean for metric jaccard
#   warnings.warn(msg, DataConversionWarning)
# #ActTrain= 115 #InactTrain= 129 #ActTest= 11 #InactTest= 16 knn1= 0.4630681818181818 lr= 0.5738636363636364 rf= 0.6534090909090908 svm= 0.6420454545454545 AA-AI= -0.02181818181818182 II-IA= 0.023749999999999993 (AA-AI)+(II-IA)= 0.0019318181818182012

# %% [markdown]
# #### ***New Train and Test data from AVE output***

# %%
# Train data
activesT_murk=pd.read_csv('actives.T.smi', sep=' ', header=None)
activesT_murk.columns=['Smiles', 'label']

inactivesT_murk=pd.read_csv('inactives.T.smi', sep=' ', header=None)
inactivesT_murk.columns=['Smiles', 'label']

train_data_murk=pd.concat([activesT_murk, inactivesT_murk], axis=0)
train_data_murk=train_data_murk.reset_index(drop=True)
print('Train_murk shape:', train_data_murk.shape)
train_data_rand.to_csv('train_data_rand.csv', sep='\t', index=None)

# Test data
activesV_murk=pd.read_csv('actives.V.smi', sep=' ', header=None)
activesV_murk.columns=['Smiles', 'label']

inactivesV_murk=pd.read_csv('inactives.V.smi', sep=' ', header=None)
inactivesV_murk.columns=['Smiles', 'label']

test_data_murk=pd.concat([activesV_murk, inactivesV_murk], axis=0)
test_data_murk=test_data_murk.reset_index(drop=True)
print('Test_murk shape:', test_data_murk.shape)
test_data_murk.to_csv('test_data_murk.csv', sep='\t', index=None)
# Out:
# Train_murk shape: (244, 2)
# Test_murk shape: (27, 2)

# %% [markdown]
# ## **Revised Bias**

# %%
Revised_Bias = pd.DataFrame({'Data':['Random Split','Molecular Clustering','Scaffold-based Clustering'], 'Bias(AVE)':[0.2321, 0.1444, 0.0185], 'Revised_Bias(AVE)':[0.0037, 0.0059, 0.0019]})
Revised_Bias
# Out:
#                         Data  Bias(AVE)  Revised_Bias(AVE)
# 0               Random Split     0.2321             0.0037
# 1       Molecular Clustering     0.1444             0.0059
# 2  Scaffold-based Clustering     0.0185             0.0019

# %% [markdown]
# ### **Scaffold-based Clustering yields minimum bias. Save corresponding train/test dataset for model building.**

# %% [markdown]
# ### **Train Data**

# %%
train_data_murk.head(3)
# Out:
#                                               Smiles  label
# 0  CCCCCOC(=O)Nc1nc(=O)n([C@@H]2O[C@H](C)[C@@H](O...      1
# 1        NC(=O)C1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1      1
# 2                 Cc1ccc(Nc2c(F)cccc2Cl)c(CC(=O)O)c1      1

# %%
train_data_murk.rename(columns={'Smiles':'STD_SMILES'}, inplace=True)

# %%
train_final=pd.merge(train_data_murk, combined_murcko_clus[['STD_SMILES','Murcko_smi', 'isosmiles','New_ID','ClusterNumber', 'CompoundName', 'Drug label-based annotation']], on='STD_SMILES')
train_final=train_final[['isosmiles','STD_SMILES', 'Murcko_smi', 'New_ID', 'label', 'ClusterNumber', 'CompoundName', 'Drug label-based annotation']]
train_final.head(3)
# Out:
#                                            isosmiles  \
# 0  CCCCCOC(=O)NC1=NC(=O)N(C=C1F)[C@H]2[C@@H]([C@@...
# 1  C1CN(CCC1C(=O)N)CCCN2C3=CC=CC=C3SC4=C2C=C(C=C4)Cl
# 2           CC1=CC(=C(C=C1)NC2=C(C=CC=C2Cl)F)CC(=O)O
#
#                                           STD_SMILES  \
# 0  CCCCCOC(=O)Nc1nc(=O)n([C@@H]2O[C@H](C)[C@@H](O...
# 1        NC(=O)C1CCN(CCCN2c3ccccc3Sc3ccc(Cl)cc32)CC1
# 2                 Cc1ccc(Nc2c(F)cccc2Cl)c(CC(=O)O)c1
#
#                           Murcko_smi    New_ID  label  ClusterNumber  \
# 0              O=c1ncccn1[C@H]1CCCO1   60953_1      1             11
# 1  c1ccc2c(c1)Sc1ccccc1N2CCCN1CCCCC1    6761_1      1             42
# 2                c1ccc(Nc2ccccc2)cc1  151166_1      1              2
#
#    CompoundName Drug label-based annotation
# 0  capecitabine           Most DILI-concern
# 1    pipamazine           Most DILI-concern
# 2   lumiracoxib           Most DILI-concern

# %%
train_final.to_csv('train.csv', sep='\t', index=None)

# %% [markdown]
# ### **Test Data**

# %%
test_data_murk.head(3)
# Out:
#                                           STD_SMILES  label
# 0              COc1ccc(Cc2nccc3cc(OC)c(OC)cc23)cc1OC      1
# 1  CO/N=C(\N)c1ccc(-c2ccc(-c3ccc(/C(N)=N/OC)cc3)o...      1
# 2                           C=CCOc1ccc(CC(=O)O)cc1Cl      1

# %%
test_data_murk.rename(columns={'Smiles':'STD_SMILES'}, inplace=True)

# %%
test_final=pd.merge(test_data_murk, combined_murcko_clus[['STD_SMILES','Murcko_smi', 'isosmiles','New_ID','ClusterNumber', 'CompoundName', 'Drug label-based annotation']], on='STD_SMILES')
test_final=test_final[['isosmiles','STD_SMILES', 'Murcko_smi', 'New_ID', 'label', 'ClusterNumber', 'CompoundName', 'Drug label-based annotation']]
test_final.head()
# Out:
#                                            isosmiles  \
# 0    COC1=C(C=C(C=C1)CC2=NC=CC3=CC(=C(C=C32)OC)OC)OC
# 1  CO/N=C(\N)/C1=CC=C(C=C1)C2=CC=C(O2)C3=CC=C(C=C...
# 2                      C=CCOC1=C(C=C(C=C1)CC(=O)O)Cl
# 3  CC1(C(=O)N(C(=O)N1)C2=CC(=C(C=C2)[N+](=O)[O-])...
# 4               CN1C(S(=O)(=O)CCC1=O)C2=CC=C(C=C2)Cl
#
#                                           STD_SMILES  \
# 0              COc1ccc(Cc2nccc3cc(OC)c(OC)cc23)cc1OC
# 1  CO/N=C(\N)c1ccc(-c2ccc(-c3ccc(/C(N)=N/OC)cc3)o...
# 2                           C=CCOc1ccc(CC(=O)O)cc1Cl
# 3  CC1(C)NC(=O)N(c2ccc([N+](=O)[O-])c(C(F)(F)F)c2...
# 4                  CN1C(=O)CCS(=O)(=O)C1c1ccc(Cl)cc1
#
#                       Murcko_smi     New_ID  label  ClusterNumber  \
# 0      c1ccc(Cc2nccc3ccccc23)cc1     4680_1      1              2
# 1  c1ccc(-c2ccc(-c3ccccc3)o2)cc1  5480200_1      1             49
# 2                       c1ccccc1    30951_1      1              1
# 3          O=C1CNC(=O)N1c1ccccc1     4493_1      1            129
# 4   O=C1CCS(=O)(=O)C(c2ccccc2)N1     2717_1      1            114
#
#     CompoundName Drug label-based annotation
# 0     papaverine           Most DILI-concern
# 1   pafuramidine           Most DILI-concern
# 2     alclofenac           Most DILI-concern
# 3     nilutamide           Most DILI-concern
# 4  chlormezanone           Most DILI-concern

# %%
test_final.to_csv('test.csv', sep='\t', index=None)
